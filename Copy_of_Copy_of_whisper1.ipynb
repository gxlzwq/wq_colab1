# %% [markdown]
# <a href="https://colab.research.google.com/github/gxlzwq/wq_colab1/blob/main/Copy_of_Copy_of_whisper1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/openai/whisper.git

# %%
# !sudo apt update && sudo apt install ffmpeg

# %%
# !whisper "/content/drive/MyDrive/mp3/unit9.mp3" --model medium --language en

# %%
# !whisper "new_jh5_m6u3a6.mp3" --model medium --language en
